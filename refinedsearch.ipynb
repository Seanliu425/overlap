# %%
import pandas as pd
import requests
from difflib import SequenceMatcher
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


def fuzzy_match(address1, address2):
    # Calculate similarity score between two addresses using SequenceMatcher
    return SequenceMatcher(None, address1.lower(), address2.lower()).ratio()

def get_most_relevant_business(address, api_key, initial_radius=20, max_radius=500, min_results=5, timeout=30):
    # Use Geocoding API to get latitude and longitude for the address
    geocoding_endpoint = "https://maps.googleapis.com/maps/api/geocode/json"
    geocoding_params = {
        "address": address,
        "key": api_key
    }
    try:
        geocoding_response = requests.get(geocoding_endpoint, params=geocoding_params, timeout=timeout)
        geocoding_response.raise_for_status()  # Raise an exception for HTTP errors
        geocoding_data = geocoding_response.json()
        
        if geocoding_data.get('results'):
            input_address = geocoding_data['results'][0]['formatted_address']
            location = geocoding_data['results'][0]['geometry']['location']
            
            # Check if the current address is the same as the previous one
            if get_most_relevant_business.prev_address and fuzzy_match(get_most_relevant_business.prev_address, input_address) == 1:
                logging.info(f"Skipping redundant address: {input_address}")
                return None
            
            get_most_relevant_business.prev_address = input_address  # Update previous address
            
            # Initialize search radius
            search_radius = initial_radius
            
            while True:
                # Use Nearby Search API to find businesses near the specified location
                nearby_search_endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
                nearby_search_params = {
                    "location": f"{location['lat']},{location['lng']}",
                    "radius": search_radius,
                    "key": api_key
                }
                response = requests.get(nearby_search_endpoint, params=nearby_search_params, timeout=timeout)
                response.raise_for_status()  # Raise an exception for HTTP errors
                data = response.json()
                
                if data.get('results'):
                    # Adjust search radius based on number of results
                    num_results = len(data['results'])
                    if num_results < min_results and search_radius < max_radius:
                        search_radius *= 2  # Double the radius
                    elif num_results > min_results:
                        break  # Sufficient number of results, exit loop
                    else:
                        break  # Maximum radius reached without enough results, exit loop
                
            max_score = 0.6 #minimum match score
            most_relevant_business = None
            for result in data['results']:
                formatted_address = result.get('vicinity', '').lower()
                # Exclude results with formatted address exactly "Chicago"
                if formatted_address != "chicago":
                    match_score = fuzzy_match(input_address, formatted_address)
                    if match_score > max_score:
                        max_score = match_score
                        most_relevant_business = {
                            "name": result.get('name'),
                            "formatted_address": formatted_address,
                            "types": result.get('types'),
                            "place_id": result.get('place_id'),
                            "match_score": match_score
                        }
            return most_relevant_business
    except requests.Timeout:
        logging.error(f"Request timed out for address: {address}")
    except requests.HTTPError as e:
        logging.error(f"HTTP error occurred: {e}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")
    return None
get_most_relevant_business.prev_address = None
def process_addresses(input_csv, output_csv, api_key, batch_size=50, timeout=30):
    # Read input CSV file
    df = pd.read_csv(input_csv)
    
    # Add new columns for business information
    df['Name'] = ""
    df['Formatted Address'] = ""
    df['Types'] = ""
    df['Match Score'] = ""
    
    total_addresses = len(df)
    num_batches = total_addresses // batch_size + (1 if total_addresses % batch_size > 0 else 0)
    
    # Process addresses in batches
    for batch_num in range(num_batches):
        logging.info(f"Processing batch {batch_num + 1} of {num_batches}")
        start_index = batch_num * batch_size
        end_index = min((batch_num + 1) * batch_size, total_addresses)
        
        # Process addresses in the current batch
        for index in range(start_index, end_index):
            address = df.at[index, 'Address']
            logging.info(f"Processing address {index + 1} of {total_addresses}")
            try:
                business = get_most_relevant_business(address, api_key, timeout=timeout)
                if business:
                    # Update DataFrame with business information
                    df.at[index, 'Name'] = business.get('name', '')
                    df.at[index, 'Formatted Address'] = business.get('formatted_address', '')
                    df.at[index, 'Types'] = ', '.join(business.get('types', []))
                    df.at[index, 'Match Score'] = round(business.get('match_score', 0), 2)  # Round match score to 2 decimal places
            except requests.Timeout:
                logging.error(f"Request timed out for address {index + 1}. Skipping...")
        
        # Save DataFrame with updated information to output CSV file after processing each batch
        df[start_index:end_index].to_csv(output_csv, index=False, mode='a' if batch_num > 0 else 'w', header=batch_num == 0)
        
        # Pause for a while before processing the next batch
        if batch_num < num_batches - 1:
            logging.info("Pausing before processing the next batch...")
            time.sleep(15)  # Pause for 15 seconds (adjust as needed)

    logging.info("Processing complete.")


# Example usage
input_csv = "mcmfproblem.csv"
output_csv = "mcmfoutputv7.csv"
api_key = "AIzaSyCaPJnC2jYbfkrtmWa0QwZJJ__xhip_Lwo"
process_addresses(input_csv, output_csv, api_key, timeout=15)
# Out:
# 2024-04-30 10:39:31,687 - INFO - Processing batch 1 of 9
# 2024-04-30 10:39:31,688 - INFO - Processing address 1 of 434
# 2024-04-30 10:39:32,210 - INFO - Processing address 2 of 434
# 2024-04-30 10:39:32,446 - INFO - Processing address 3 of 434
# 2024-04-30 10:39:32,942 - INFO - Processing address 4 of 434
# 2024-04-30 10:39:33,036 - INFO - Processing address 5 of 434
# 2024-04-30 10:39:33,379 - INFO - Processing address 6 of 434
# 2024-04-30 10:39:33,746 - INFO - Processing address 7 of 434
# 2024-04-30 10:39:34,023 - INFO - Processing address 8 of 434
# 2024-04-30 10:39:34,318 - INFO - Processing address 9 of 434
# 2024-04-30 10:39:34,641 - INFO - Processing address 10 of 434
# 2024-04-30 10:39:34,999 - INFO - Processing address 11 of 434
# 2024-04-30 10:39:35,523 - INFO - Processing address 12 of 434
# 2024-04-30 10:39:36,541 - INFO - Processing address 13 of 434
# 2024-04-30 10:39:37,153 - INFO - Processing address 14 of 434
# 2024-04-30 10:39:37,553 - INFO - Processing address 15 of 434
# 2024-04-30 10:39:38,288 - INFO - Processing address 16 of 434
# 2024-04-30 10:39:38,440 - INFO - Processing address 17 of 434
# 2024-04-30 10:39:38,864 - INFO - Processing address 18 of 434
# 2024-04-30 10:39:39,689 - INFO - Processing address 19 of 434
# 2024-04-30 10:39:40,969 - INFO - Processing address 20 of 434
# 2024-04-30 10:39:41,631 - INFO - Processing address 21 of 434
# 2024-04-30 10:39:42,245 - INFO - Processing address 22 of 434
# 2024-04-30 10:39:42,631 - INFO - Processing address 23 of 434
# 2024-04-30 10:39:43,398 - INFO - Processing address 24 of 434
# 2024-04-30 10:39:44,494 - INFO - Processing address 25 of 434
# 2024-04-30 10:39:44,917 - INFO - Processing address 26 of 434
# 2024-04-30 10:39:45,523 - INFO - Processing address 27 of 434
# 2024-04-30 10:39:46,184 - INFO - Processing address 28 of 434
# 2024-04-30 10:39:46,617 - INFO - Processing address 29 of 434
# 2024-04-30 10:39:47,439 - INFO - Processing address 30 of 434
# 2024-04-30 10:39:48,195 - INFO - Processing address 31 of 434
# 2024-04-30 10:39:49,013 - INFO - Processing address 32 of 434
# 2024-04-30 10:39:49,626 - INFO - Processing address 33 of 434
# 2024-04-30 10:39:50,383 - INFO - Processing address 34 of 434
# 2024-04-30 10:39:51,007 - INFO - Processing address 35 of 434
# 2024-04-30 10:39:51,471 - INFO - Processing address 36 of 434
# 2024-04-30 10:39:52,905 - INFO - Processing address 37 of 434
# 2024-04-30 10:39:53,882 - INFO - Processing address 38 of 434
# 2024-04-30 10:39:54,678 - INFO - Processing address 39 of 434
# 2024-04-30 10:39:55,081 - INFO - Processing address 40 of 434
# 2024-04-30 10:39:55,900 - INFO - Processing address 41 of 434
# 2024-04-30 10:39:56,557 - INFO - Processing address 42 of 434
# 2024-04-30 10:39:56,741 - INFO - Processing address 43 of 434
# 2024-04-30 10:39:57,511 - INFO - Processing address 44 of 434
# 2024-04-30 10:39:58,486 - INFO - Processing address 45 of 434
# 2024-04-30 10:39:59,264 - INFO - Processing address 46 of 434
# 2024-04-30 10:39:59,667 - INFO - Processing address 47 of 434
# 2024-04-30 10:40:00,082 - INFO - Processing address 48 of 434
# 2024-04-30 10:40:01,293 - INFO - Processing address 49 of 434
# 2024-04-30 10:40:01,995 - INFO - Processing address 50 of 434
# 2024-04-30 10:40:02,564 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:40:17,570 - INFO - Processing batch 2 of 9
# 2024-04-30 10:40:17,575 - INFO - Processing address 51 of 434
# 2024-04-30 10:40:18,385 - INFO - Processing address 52 of 434
# 2024-04-30 10:40:18,777 - INFO - Processing address 53 of 434
# 2024-04-30 10:40:19,568 - INFO - Processing address 54 of 434
# 2024-04-30 10:40:20,487 - INFO - Processing address 55 of 434
# 2024-04-30 10:40:20,881 - INFO - Processing address 56 of 434
# 2024-04-30 10:40:21,289 - INFO - Processing address 57 of 434
# 2024-04-30 10:40:22,096 - INFO - Processing address 58 of 434
# 2024-04-30 10:40:22,881 - INFO - Processing address 59 of 434
# 2024-04-30 10:40:23,605 - INFO - Processing address 60 of 434
# 2024-04-30 10:40:24,409 - INFO - Processing address 61 of 434
# 2024-04-30 10:40:24,839 - INFO - Processing address 62 of 434
# 2024-04-30 10:40:25,487 - INFO - Processing address 63 of 434
# 2024-04-30 10:40:26,172 - INFO - Processing address 64 of 434
# 2024-04-30 10:40:26,971 - INFO - Processing address 65 of 434
# 2024-04-30 10:40:27,813 - INFO - Processing address 66 of 434
# 2024-04-30 10:40:28,560 - INFO - Processing address 67 of 434
# 2024-04-30 10:40:29,360 - INFO - Processing address 68 of 434
# 2024-04-30 10:40:30,112 - INFO - Processing address 69 of 434
# 2024-04-30 10:40:30,523 - INFO - Processing address 70 of 434
# 2024-04-30 10:40:31,290 - INFO - Processing address 71 of 434
# 2024-04-30 10:40:31,994 - INFO - Processing address 72 of 434
# 2024-04-30 10:40:32,916 - INFO - Processing address 73 of 434
# 2024-04-30 10:40:33,729 - INFO - Processing address 74 of 434
# 2024-04-30 10:40:34,499 - INFO - Processing address 75 of 434
# 2024-04-30 10:40:35,193 - INFO - Processing address 76 of 434
# 2024-04-30 10:40:35,983 - INFO - Processing address 77 of 434
# 2024-04-30 10:40:36,551 - INFO - Processing address 78 of 434
# 2024-04-30 10:40:37,294 - INFO - Processing address 79 of 434
# 2024-04-30 10:40:38,020 - INFO - Processing address 80 of 434
# 2024-04-30 10:40:38,887 - INFO - Processing address 81 of 434
# 2024-04-30 10:40:39,330 - INFO - Processing address 82 of 434
# 2024-04-30 10:40:40,113 - INFO - Processing address 83 of 434
# 2024-04-30 10:40:40,695 - INFO - Processing address 84 of 434
# 2024-04-30 10:40:41,521 - INFO - Processing address 85 of 434
# 2024-04-30 10:40:42,163 - INFO - Processing address 86 of 434
# 2024-04-30 10:40:42,733 - INFO - Processing address 87 of 434
# 2024-04-30 10:40:43,181 - INFO - Processing address 88 of 434
# 2024-04-30 10:40:43,746 - INFO - Processing address 89 of 434
# 2024-04-30 10:40:44,357 - INFO - Processing address 90 of 434
# 2024-04-30 10:40:45,509 - INFO - Processing address 91 of 434
# 2024-04-30 10:40:45,690 - INFO - Processing address 92 of 434
# 2024-04-30 10:40:46,681 - INFO - Processing address 93 of 434
# 2024-04-30 10:40:47,282 - INFO - Processing address 94 of 434
# 2024-04-30 10:40:47,864 - INFO - Processing address 95 of 434
# 2024-04-30 10:40:48,242 - INFO - Processing address 96 of 434
# 2024-04-30 10:40:48,994 - INFO - Processing address 97 of 434
# 2024-04-30 10:40:50,488 - INFO - Processing address 98 of 434
# 2024-04-30 10:40:50,910 - INFO - Processing address 99 of 434
# 2024-04-30 10:40:51,363 - INFO - Processing address 100 of 434
# 2024-04-30 10:40:51,809 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:41:06,814 - INFO - Processing batch 3 of 9
# 2024-04-30 10:41:06,822 - INFO - Processing address 101 of 434
# 2024-04-30 10:41:07,655 - INFO - Processing address 102 of 434
# 2024-04-30 10:41:08,066 - INFO - Processing address 103 of 434
# 2024-04-30 10:41:08,611 - INFO - Processing address 104 of 434
# 2024-04-30 10:41:09,017 - INFO - Processing address 105 of 434
# 2024-04-30 10:41:09,544 - INFO - Processing address 106 of 434
# 2024-04-30 10:41:09,971 - INFO - Processing address 107 of 434
# 2024-04-30 10:41:10,760 - INFO - Processing address 108 of 434
# 2024-04-30 10:41:11,355 - INFO - Processing address 109 of 434
# 2024-04-30 10:41:12,392 - INFO - Processing address 110 of 434
# 2024-04-30 10:41:13,664 - INFO - Processing address 111 of 434
# 2024-04-30 10:41:14,411 - INFO - Processing address 112 of 434
# 2024-04-30 10:41:15,047 - INFO - Processing address 113 of 434
# 2024-04-30 10:41:16,321 - INFO - Processing address 114 of 434
# 2024-04-30 10:41:16,721 - INFO - Processing address 115 of 434
# 2024-04-30 10:41:17,578 - INFO - Processing address 116 of 434
# 2024-04-30 10:41:18,861 - INFO - Processing address 117 of 434
# 2024-04-30 10:41:19,475 - INFO - Processing address 118 of 434
# 2024-04-30 10:41:19,887 - INFO - Processing address 119 of 434
# 2024-04-30 10:41:20,304 - INFO - Processing address 120 of 434
# 2024-04-30 10:41:20,738 - INFO - Processing address 121 of 434
# 2024-04-30 10:41:21,450 - INFO - Processing address 122 of 434
# 2024-04-30 10:41:22,613 - INFO - Processing address 123 of 434
# 2024-04-30 10:41:23,004 - INFO - Processing address 124 of 434
# 2024-04-30 10:41:24,001 - INFO - Processing address 125 of 434
# 2024-04-30 10:41:24,163 - INFO - Processing address 126 of 434
# 2024-04-30 10:41:25,060 - INFO - Processing address 127 of 434
# 2024-04-30 10:41:25,959 - INFO - Processing address 128 of 434
# 2024-04-30 10:41:26,963 - INFO - Processing address 129 of 434
# 2024-04-30 10:41:27,931 - INFO - Processing address 130 of 434
# 2024-04-30 10:41:28,845 - INFO - Processing address 131 of 434
# 2024-04-30 10:41:29,883 - INFO - Processing address 132 of 434
# 2024-04-30 10:41:30,867 - INFO - Processing address 133 of 434
# 2024-04-30 10:41:31,027 - INFO - Processing address 134 of 434
# 2024-04-30 10:41:31,623 - INFO - Processing address 135 of 434
# 2024-04-30 10:41:32,041 - INFO - Processing address 136 of 434
# 2024-04-30 10:41:33,229 - INFO - Processing address 137 of 434
# 2024-04-30 10:41:33,875 - INFO - Processing address 138 of 434
# 2024-04-30 10:41:34,593 - INFO - Processing address 139 of 434
# 2024-04-30 10:41:35,338 - INFO - Processing address 140 of 434
# 2024-04-30 10:41:36,203 - INFO - Processing address 141 of 434
# 2024-04-30 10:41:36,890 - INFO - Processing address 142 of 434
# 2024-04-30 10:41:37,877 - INFO - Processing address 143 of 434
# 2024-04-30 10:41:38,476 - INFO - Processing address 144 of 434
# 2024-04-30 10:41:39,140 - INFO - Processing address 145 of 434
# 2024-04-30 10:41:39,579 - INFO - Processing address 146 of 434
# 2024-04-30 10:41:40,353 - INFO - Processing address 147 of 434
# 2024-04-30 10:41:41,032 - INFO - Processing address 148 of 434
# 2024-04-30 10:41:41,812 - INFO - Processing address 149 of 434
# 2024-04-30 10:41:42,263 - INFO - Processing address 150 of 434
# 2024-04-30 10:41:43,023 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:41:58,030 - INFO - Processing batch 4 of 9
# 2024-04-30 10:41:58,048 - INFO - Processing address 151 of 434
# 2024-04-30 10:41:59,117 - INFO - Processing address 152 of 434
# 2024-04-30 10:41:59,979 - INFO - Processing address 153 of 434
# 2024-04-30 10:42:01,708 - INFO - Processing address 154 of 434
# 2024-04-30 10:42:02,289 - INFO - Processing address 155 of 434
# 2024-04-30 10:42:02,806 - INFO - Processing address 156 of 434
# 2024-04-30 10:42:03,735 - INFO - Processing address 157 of 434
# 2024-04-30 10:42:04,576 - INFO - Processing address 158 of 434
# 2024-04-30 10:42:05,625 - INFO - Processing address 159 of 434
# 2024-04-30 10:42:06,797 - INFO - Processing address 160 of 434
# 2024-04-30 10:42:07,405 - INFO - Processing address 161 of 434
# 2024-04-30 10:42:08,187 - INFO - Processing address 162 of 434
# 2024-04-30 10:42:08,357 - INFO - Processing address 163 of 434
# 2024-04-30 10:42:09,088 - INFO - Processing address 164 of 434
# 2024-04-30 10:42:09,746 - INFO - Processing address 165 of 434
# 2024-04-30 10:42:10,199 - INFO - Processing address 166 of 434
# 2024-04-30 10:42:10,786 - INFO - Processing address 167 of 434
# 2024-04-30 10:42:11,659 - INFO - Processing address 168 of 434
# 2024-04-30 10:42:12,496 - INFO - Processing address 169 of 434
# 2024-04-30 10:42:12,909 - INFO - Processing address 170 of 434
# 2024-04-30 10:42:13,714 - INFO - Processing address 171 of 434
# 2024-04-30 10:42:14,416 - INFO - Processing address 172 of 434
# 2024-04-30 10:42:15,358 - INFO - Processing address 173 of 434
# 2024-04-30 10:42:15,899 - INFO - Processing address 174 of 434
# 2024-04-30 10:42:16,546 - INFO - Processing address 175 of 434
# 2024-04-30 10:42:17,544 - INFO - Processing address 176 of 434
# 2024-04-30 10:42:18,368 - INFO - Processing address 177 of 434
# 2024-04-30 10:42:18,547 - INFO - Processing address 178 of 434
# 2024-04-30 10:42:18,952 - INFO - Processing address 179 of 434
# 2024-04-30 10:42:19,355 - INFO - Processing address 180 of 434
# 2024-04-30 10:42:20,483 - INFO - Processing address 181 of 434
# 2024-04-30 10:42:21,312 - INFO - Processing address 182 of 434
# 2024-04-30 10:42:22,012 - INFO - Processing address 183 of 434
# 2024-04-30 10:42:22,735 - INFO - Processing address 184 of 434
# 2024-04-30 10:42:23,347 - INFO - Processing address 185 of 434
# 2024-04-30 10:42:24,059 - INFO - Processing address 186 of 434
# 2024-04-30 10:42:24,921 - INFO - Processing address 187 of 434
# 2024-04-30 10:42:25,325 - INFO - Processing address 188 of 434
# 2024-04-30 10:42:26,123 - INFO - Processing address 189 of 434
# 2024-04-30 10:42:27,045 - INFO - Processing address 190 of 434
# 2024-04-30 10:42:27,907 - INFO - Processing address 191 of 434
# 2024-04-30 10:42:28,469 - INFO - Processing address 192 of 434
# 2024-04-30 10:42:29,046 - INFO - Processing address 193 of 434
# 2024-04-30 10:42:30,833 - INFO - Processing address 194 of 434
# 2024-04-30 10:42:31,752 - INFO - Processing address 195 of 434
# 2024-04-30 10:42:32,817 - INFO - Processing address 196 of 434
# 2024-04-30 10:42:33,265 - INFO - Processing address 197 of 434
# 2024-04-30 10:42:34,024 - INFO - Processing address 198 of 434
# 2024-04-30 10:42:35,526 - INFO - Processing address 199 of 434
# 2024-04-30 10:42:36,345 - INFO - Processing address 200 of 434
# 2024-04-30 10:42:36,970 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:42:51,977 - INFO - Processing batch 5 of 9
# 2024-04-30 10:42:52,038 - INFO - Processing address 201 of 434
# 2024-04-30 10:42:53,312 - INFO - Processing address 202 of 434
# 2024-04-30 10:42:54,064 - INFO - Processing address 203 of 434
# 2024-04-30 10:42:54,946 - INFO - Processing address 204 of 434
# 2024-04-30 10:42:55,142 - INFO - Skipping redundant address: 7424 S Morgan St, Chicago, IL 60621, USA
# 2024-04-30 10:42:55,146 - INFO - Processing address 205 of 434
# 2024-04-30 10:42:56,181 - INFO - Processing address 206 of 434
# 2024-04-30 10:42:56,984 - INFO - Processing address 207 of 434
# 2024-04-30 10:42:57,908 - INFO - Processing address 208 of 434
# 2024-04-30 10:42:58,934 - INFO - Processing address 209 of 434
# 2024-04-30 10:43:00,314 - INFO - Processing address 210 of 434
# 2024-04-30 10:43:00,942 - INFO - Processing address 211 of 434
# 2024-04-30 10:43:01,580 - INFO - Processing address 212 of 434
# 2024-04-30 10:43:02,256 - INFO - Processing address 213 of 434
# 2024-04-30 10:43:02,654 - INFO - Processing address 214 of 434
# 2024-04-30 10:43:03,445 - INFO - Processing address 215 of 434
# 2024-04-30 10:43:04,348 - INFO - Processing address 216 of 434
# 2024-04-30 10:43:05,143 - INFO - Processing address 217 of 434
# 2024-04-30 10:43:06,335 - INFO - Processing address 218 of 434
# 2024-04-30 10:43:06,959 - INFO - Processing address 219 of 434
# 2024-04-30 10:43:07,884 - INFO - Processing address 220 of 434
# 2024-04-30 10:43:08,891 - INFO - Processing address 221 of 434
# 2024-04-30 10:43:09,829 - INFO - Processing address 222 of 434
# 2024-04-30 10:43:10,774 - INFO - Processing address 223 of 434
# 2024-04-30 10:43:11,332 - INFO - Processing address 224 of 434
# 2024-04-30 10:43:12,197 - INFO - Processing address 225 of 434
# 2024-04-30 10:43:12,683 - INFO - Processing address 226 of 434
# 2024-04-30 10:43:13,445 - INFO - Processing address 227 of 434
# 2024-04-30 10:43:13,918 - INFO - Processing address 228 of 434
# 2024-04-30 10:43:14,762 - INFO - Processing address 229 of 434
# 2024-04-30 10:43:15,614 - INFO - Processing address 230 of 434
# 2024-04-30 10:43:16,073 - INFO - Processing address 231 of 434
# 2024-04-30 10:43:17,356 - INFO - Processing address 232 of 434
# 2024-04-30 10:43:18,569 - INFO - Processing address 233 of 434
# 2024-04-30 10:43:19,573 - INFO - Processing address 234 of 434
# 2024-04-30 10:43:20,283 - INFO - Processing address 235 of 434
# 2024-04-30 10:43:20,943 - INFO - Processing address 236 of 434
# 2024-04-30 10:43:21,507 - INFO - Processing address 237 of 434
# 2024-04-30 10:43:21,690 - INFO - Processing address 238 of 434
# 2024-04-30 10:43:22,419 - INFO - Processing address 239 of 434
# 2024-04-30 10:43:23,472 - INFO - Processing address 240 of 434
# 2024-04-30 10:43:24,129 - INFO - Processing address 241 of 434
# 2024-04-30 10:43:25,694 - INFO - Processing address 242 of 434
# 2024-04-30 10:43:26,444 - INFO - Processing address 243 of 434
# 2024-04-30 10:43:26,646 - INFO - Processing address 244 of 434
# 2024-04-30 10:43:27,470 - INFO - Processing address 245 of 434
# 2024-04-30 10:43:27,897 - INFO - Processing address 246 of 434
# 2024-04-30 10:43:28,712 - INFO - Processing address 247 of 434
# 2024-04-30 10:43:29,984 - INFO - Processing address 248 of 434
# 2024-04-30 10:43:30,986 - INFO - Processing address 249 of 434
# 2024-04-30 10:43:31,409 - INFO - Processing address 250 of 434
# 2024-04-30 10:43:32,153 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:43:47,159 - INFO - Processing batch 6 of 9
# 2024-04-30 10:43:47,161 - INFO - Processing address 251 of 434
# 2024-04-30 10:43:47,951 - INFO - Processing address 252 of 434
# 2024-04-30 10:43:48,396 - INFO - Processing address 253 of 434
# 2024-04-30 10:43:49,113 - INFO - Processing address 254 of 434
# 2024-04-30 10:43:50,219 - INFO - Processing address 255 of 434
# 2024-04-30 10:43:51,102 - INFO - Processing address 256 of 434
# 2024-04-30 10:43:51,597 - INFO - Processing address 257 of 434
# 2024-04-30 10:43:52,292 - INFO - Processing address 258 of 434
# 2024-04-30 10:43:53,360 - INFO - Processing address 259 of 434
# 2024-04-30 10:43:53,824 - INFO - Processing address 260 of 434
# 2024-04-30 10:43:54,915 - INFO - Processing address 261 of 434
# 2024-04-30 10:43:55,901 - INFO - Processing address 262 of 434
# 2024-04-30 10:43:57,428 - INFO - Processing address 263 of 434
# 2024-04-30 10:43:58,338 - INFO - Processing address 264 of 434
# 2024-04-30 10:43:59,757 - INFO - Processing address 265 of 434
# 2024-04-30 10:44:00,887 - INFO - Processing address 266 of 434
# 2024-04-30 10:44:01,347 - INFO - Processing address 267 of 434
# 2024-04-30 10:44:02,195 - INFO - Processing address 268 of 434
# 2024-04-30 10:44:03,062 - INFO - Processing address 269 of 434
# 2024-04-30 10:44:04,082 - INFO - Processing address 270 of 434
# 2024-04-30 10:44:04,587 - INFO - Processing address 271 of 434
# 2024-04-30 10:44:05,630 - INFO - Processing address 272 of 434
# 2024-04-30 10:44:05,824 - INFO - Processing address 273 of 434
# 2024-04-30 10:44:06,831 - INFO - Processing address 274 of 434
# 2024-04-30 10:44:07,612 - INFO - Processing address 275 of 434
# 2024-04-30 10:44:08,316 - INFO - Processing address 276 of 434
# 2024-04-30 10:44:08,873 - INFO - Processing address 277 of 434
# 2024-04-30 10:44:10,017 - INFO - Processing address 278 of 434
# 2024-04-30 10:44:10,880 - INFO - Processing address 279 of 434
# 2024-04-30 10:44:11,823 - INFO - Processing address 280 of 434
# 2024-04-30 10:44:12,847 - INFO - Processing address 281 of 434
# 2024-04-30 10:44:13,375 - INFO - Processing address 282 of 434
# 2024-04-30 10:44:14,130 - INFO - Processing address 283 of 434
# 2024-04-30 10:44:15,036 - INFO - Processing address 284 of 434
# 2024-04-30 10:44:15,811 - INFO - Processing address 285 of 434
# 2024-04-30 10:44:16,658 - INFO - Processing address 286 of 434
# 2024-04-30 10:44:17,686 - INFO - Processing address 287 of 434
# 2024-04-30 10:44:18,155 - INFO - Processing address 288 of 434
# 2024-04-30 10:44:19,090 - INFO - Processing address 289 of 434
# 2024-04-30 10:44:19,596 - INFO - Processing address 290 of 434
# 2024-04-30 10:44:20,489 - INFO - Processing address 291 of 434
# 2024-04-30 10:44:20,923 - INFO - Processing address 292 of 434
# 2024-04-30 10:44:21,468 - INFO - Processing address 293 of 434
# 2024-04-30 10:44:22,642 - INFO - Processing address 294 of 434
# 2024-04-30 10:44:23,493 - INFO - Processing address 295 of 434
# 2024-04-30 10:44:24,404 - INFO - Processing address 296 of 434
# 2024-04-30 10:44:25,015 - INFO - Processing address 297 of 434
# 2024-04-30 10:44:25,854 - INFO - Processing address 298 of 434
# 2024-04-30 10:44:26,473 - INFO - Processing address 299 of 434
# 2024-04-30 10:44:27,813 - INFO - Processing address 300 of 434
# 2024-04-30 10:44:28,700 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:44:43,703 - INFO - Processing batch 7 of 9
# 2024-04-30 10:44:43,711 - INFO - Processing address 301 of 434
# 2024-04-30 10:44:43,877 - INFO - Processing address 302 of 434
# 2024-04-30 10:44:44,256 - INFO - Processing address 303 of 434
# 2024-04-30 10:44:44,656 - INFO - Processing address 304 of 434
# 2024-04-30 10:44:45,067 - INFO - Processing address 305 of 434
# 2024-04-30 10:44:45,963 - INFO - Processing address 306 of 434
# 2024-04-30 10:44:47,006 - INFO - Processing address 307 of 434
# 2024-04-30 10:44:47,831 - INFO - Processing address 308 of 434
# 2024-04-30 10:44:48,870 - INFO - Processing address 309 of 434
# 2024-04-30 10:44:50,415 - INFO - Processing address 310 of 434
# 2024-04-30 10:44:50,859 - INFO - Processing address 311 of 434
# 2024-04-30 10:44:51,283 - INFO - Processing address 312 of 434
# 2024-04-30 10:44:52,000 - INFO - Processing address 313 of 434
# 2024-04-30 10:44:52,877 - INFO - Processing address 314 of 434
# 2024-04-30 10:44:53,873 - INFO - Processing address 315 of 434
# 2024-04-30 10:44:54,691 - INFO - Processing address 316 of 434
# 2024-04-30 10:44:55,311 - INFO - Processing address 317 of 434
# 2024-04-30 10:44:56,081 - INFO - Processing address 318 of 434
# 2024-04-30 10:44:57,116 - INFO - Processing address 319 of 434
# 2024-04-30 10:44:57,900 - INFO - Processing address 320 of 434
# 2024-04-30 10:44:58,310 - INFO - Processing address 321 of 434
# 2024-04-30 10:44:58,929 - INFO - Processing address 322 of 434
# 2024-04-30 10:45:00,830 - INFO - Processing address 323 of 434
# 2024-04-30 10:45:01,329 - INFO - Processing address 324 of 434
# 2024-04-30 10:45:02,125 - INFO - Processing address 325 of 434
# 2024-04-30 10:45:02,826 - INFO - Processing address 326 of 434
# 2024-04-30 10:45:03,233 - INFO - Processing address 327 of 434
# 2024-04-30 10:45:03,799 - INFO - Processing address 328 of 434
# 2024-04-30 10:45:04,975 - INFO - Processing address 329 of 434
# 2024-04-30 10:45:06,234 - INFO - Processing address 330 of 434
# 2024-04-30 10:45:06,915 - INFO - Processing address 331 of 434
# 2024-04-30 10:45:07,336 - INFO - Processing address 332 of 434
# 2024-04-30 10:45:08,013 - INFO - Processing address 333 of 434
# 2024-04-30 10:45:08,998 - INFO - Processing address 334 of 434
# 2024-04-30 10:45:09,736 - INFO - Processing address 335 of 434
# 2024-04-30 10:45:10,161 - INFO - Processing address 336 of 434
# 2024-04-30 10:45:10,920 - INFO - Processing address 337 of 434
# 2024-04-30 10:45:11,549 - INFO - Processing address 338 of 434
# 2024-04-30 10:45:12,368 - INFO - Processing address 339 of 434
# 2024-04-30 10:45:12,523 - INFO - Processing address 340 of 434
# 2024-04-30 10:45:12,696 - INFO - Processing address 341 of 434
# 2024-04-30 10:45:12,861 - INFO - Processing address 342 of 434
# 2024-04-30 10:45:13,549 - INFO - Processing address 343 of 434
# 2024-04-30 10:45:13,933 - INFO - Processing address 344 of 434
# 2024-04-30 10:45:14,619 - INFO - Processing address 345 of 434
# 2024-04-30 10:45:14,997 - INFO - Processing address 346 of 434
# 2024-04-30 10:45:15,593 - INFO - Processing address 347 of 434
# 2024-04-30 10:45:15,991 - INFO - Processing address 348 of 434
# 2024-04-30 10:45:16,762 - INFO - Processing address 349 of 434
# 2024-04-30 10:45:17,618 - INFO - Processing address 350 of 434
# 2024-04-30 10:45:18,012 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:45:33,016 - INFO - Processing batch 8 of 9
# 2024-04-30 10:45:33,052 - INFO - Processing address 351 of 434
# 2024-04-30 10:45:33,638 - INFO - Processing address 352 of 434
# 2024-04-30 10:45:34,599 - INFO - Processing address 353 of 434
# 2024-04-30 10:45:35,384 - INFO - Processing address 354 of 434
# 2024-04-30 10:45:36,000 - INFO - Processing address 355 of 434
# 2024-04-30 10:45:36,790 - INFO - Processing address 356 of 434
# 2024-04-30 10:45:37,743 - INFO - Processing address 357 of 434
# 2024-04-30 10:45:38,630 - INFO - Processing address 358 of 434
# 2024-04-30 10:45:39,265 - INFO - Processing address 359 of 434
# 2024-04-30 10:45:39,720 - INFO - Processing address 360 of 434
# 2024-04-30 10:45:40,552 - INFO - Processing address 361 of 434
# 2024-04-30 10:45:41,180 - INFO - Processing address 362 of 434
# 2024-04-30 10:45:41,811 - INFO - Processing address 363 of 434
# 2024-04-30 10:45:42,576 - INFO - Processing address 364 of 434
# 2024-04-30 10:45:43,062 - INFO - Processing address 365 of 434
# 2024-04-30 10:45:43,722 - INFO - Processing address 366 of 434
# 2024-04-30 10:45:44,305 - INFO - Processing address 367 of 434
# 2024-04-30 10:45:45,234 - INFO - Processing address 368 of 434
# 2024-04-30 10:45:46,254 - INFO - Processing address 369 of 434
# 2024-04-30 10:45:46,700 - INFO - Processing address 370 of 434
# 2024-04-30 10:45:46,859 - INFO - Processing address 371 of 434
# 2024-04-30 10:45:47,060 - INFO - Processing address 372 of 434
# 2024-04-30 10:45:48,124 - INFO - Processing address 373 of 434
# 2024-04-30 10:45:49,189 - INFO - Processing address 374 of 434
# 2024-04-30 10:45:49,886 - INFO - Processing address 375 of 434
# 2024-04-30 10:45:50,846 - INFO - Processing address 376 of 434
# 2024-04-30 10:45:51,074 - INFO - Processing address 377 of 434
# 2024-04-30 10:45:51,980 - INFO - Processing address 378 of 434
# 2024-04-30 10:45:53,011 - INFO - Processing address 379 of 434
# 2024-04-30 10:45:54,162 - INFO - Processing address 380 of 434
# 2024-04-30 10:45:54,965 - INFO - Processing address 381 of 434
# 2024-04-30 10:45:55,154 - INFO - Processing address 382 of 434
# 2024-04-30 10:45:56,413 - INFO - Processing address 383 of 434
# 2024-04-30 10:45:57,236 - INFO - Processing address 384 of 434
# 2024-04-30 10:45:57,645 - INFO - Processing address 385 of 434
# 2024-04-30 10:45:58,439 - INFO - Processing address 386 of 434
# 2024-04-30 10:45:59,432 - INFO - Processing address 387 of 434
# 2024-04-30 10:46:00,621 - INFO - Processing address 388 of 434
# 2024-04-30 10:46:01,758 - INFO - Processing address 389 of 434
# 2024-04-30 10:46:03,244 - INFO - Processing address 390 of 434
# 2024-04-30 10:46:04,159 - INFO - Processing address 391 of 434
# 2024-04-30 10:46:05,038 - INFO - Processing address 392 of 434
# 2024-04-30 10:46:06,158 - INFO - Processing address 393 of 434
# 2024-04-30 10:46:07,678 - INFO - Processing address 394 of 434
# 2024-04-30 10:46:08,690 - INFO - Processing address 395 of 434
# 2024-04-30 10:46:09,411 - INFO - Processing address 396 of 434
# 2024-04-30 10:46:10,262 - INFO - Processing address 397 of 434
# 2024-04-30 10:46:11,132 - INFO - Processing address 398 of 434
# 2024-04-30 10:46:11,766 - INFO - Processing address 399 of 434
# 2024-04-30 10:46:12,319 - INFO - Processing address 400 of 434
# 2024-04-30 10:46:13,845 - INFO - Pausing before processing the next batch...
# 2024-04-30 10:46:28,855 - INFO - Processing batch 9 of 9
# 2024-04-30 10:46:28,876 - INFO - Processing address 401 of 434
# 2024-04-30 10:46:29,088 - INFO - Processing address 402 of 434
# 2024-04-30 10:46:29,828 - INFO - Processing address 403 of 434
# 2024-04-30 10:46:30,229 - INFO - Processing address 404 of 434
# 2024-04-30 10:46:30,868 - INFO - Processing address 405 of 434
# 2024-04-30 10:46:31,449 - INFO - Processing address 406 of 434
# 2024-04-30 10:46:33,063 - INFO - Processing address 407 of 434
# 2024-04-30 10:46:33,964 - INFO - Processing address 408 of 434
# 2024-04-30 10:46:34,911 - INFO - Processing address 409 of 434
# 2024-04-30 10:46:35,691 - INFO - Processing address 410 of 434
# 2024-04-30 10:46:37,018 - INFO - Processing address 411 of 434
# 2024-04-30 10:46:37,382 - INFO - Processing address 412 of 434
# 2024-04-30 10:46:38,182 - INFO - Processing address 413 of 434
# 2024-04-30 10:46:38,388 - INFO - Processing address 414 of 434
# 2024-04-30 10:46:39,372 - INFO - Processing address 415 of 434
# 2024-04-30 10:46:40,370 - INFO - Processing address 416 of 434
# 2024-04-30 10:46:41,416 - INFO - Processing address 417 of 434
# 2024-04-30 10:46:41,568 - INFO - Processing address 418 of 434
# 2024-04-30 10:46:42,448 - INFO - Processing address 419 of 434
# 2024-04-30 10:46:42,603 - INFO - Processing address 420 of 434
# 2024-04-30 10:46:43,138 - INFO - Processing address 421 of 434
# 2024-04-30 10:46:44,023 - INFO - Processing address 422 of 434
# 2024-04-30 10:46:44,709 - INFO - Processing address 423 of 434
# 2024-04-30 10:46:45,137 - INFO - Processing address 424 of 434
# 2024-04-30 10:46:45,903 - INFO - Processing address 425 of 434
# 2024-04-30 10:46:46,076 - INFO - Processing address 426 of 434
# 2024-04-30 10:46:46,511 - INFO - Processing address 427 of 434
# 2024-04-30 10:46:47,358 - INFO - Processing address 428 of 434
# 2024-04-30 10:46:48,269 - INFO - Processing address 429 of 434
# 2024-04-30 10:46:48,731 - INFO - Processing address 430 of 434
# 2024-04-30 10:46:49,669 - INFO - Processing address 431 of 434
# 2024-04-30 10:46:50,442 - INFO - Processing address 432 of 434
# 2024-04-30 10:46:50,827 - INFO - Processing address 433 of 434
# 2024-04-30 10:46:51,470 - INFO - Processing address 434 of 434
# 2024-04-30 10:46:51,673 - INFO - Processing complete.

# %%
import re
import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_excel('MCMF_Cleaned.xlsx')

# Define a function to extract digits from a string
def extract_digits(text):
    return ''.join(re.findall(r'\d+', str(text)))

# Apply the function to the two columns in the DataFrame
df['Digits_Column1'] = df['Address'].apply(extract_digits)
df['Digits_Column2'] = df['Formatted Address'].apply(extract_digits)

# Compare the extracted digits and create a new column indicating whether they match
df['Digits_Match'] = df['Digits_Column1'] == df['Digits_Column2']

# Save the DataFrame to a new Excel file
df.to_excel('output_file.xlsx', index=False)
